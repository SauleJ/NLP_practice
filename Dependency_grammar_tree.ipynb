# %% [markdown]
# #### 1. Provide a dependency grammar tree. Print nodes and dependency tags

# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

text = 'The students exam scores were all fantastic'
doc = nlp(text)

for token in doc:
    print(f"{token.text.ljust(10)} {token.lemma_.ljust(10)} {token.pos_.ljust(6)} {token.head.text.ljust(10)} {token.dep_.ljust(8)}")

options = {"compact": False, "color": "#FFD700", "bg": "#8A2BE2", "font": "Source Sans Pro"}

html_output = displacy.render(doc, style='dep', options=options)
# Out:
# The        the        DET    students   det
# students   student    NOUN   scores     compound
# exam       exam       NOUN   scores     compound
# scores     score      NOUN   were       nsubj
# were       be         AUX    were       ROOT
# all        all        PRON   were       dep
# fantastic  fantastic  ADJ    were       acomp
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="aa22c479d2894605b98a560342096510-0" class="displacy" width="1275" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #FFD700; background: #8A2BE2; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">students</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">exam</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">scores</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">were</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">fantastic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aa22c479d2894605b98a560342096510-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aa22c479d2894605b98a560342096510-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aa22c479d2894605b98a560342096510-0-1" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aa22c479d2894605b98a560342096510-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aa22c479d2894605b98a560342096510-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aa22c479d2894605b98a560342096510-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aa22c479d2894605b98a560342096510-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aa22c479d2894605b98a560342096510-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aa22c479d2894605b98a560342096510-0-4" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aa22c479d2894605b98a560342096510-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,179.0 L928.0,167.0 912.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aa22c479d2894605b98a560342096510-0-5" stroke-width="2px" d="M770,177.0 C770,2.0 1100.0,2.0 1100.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aa22c479d2894605b98a560342096510-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,179.0 L1108.0,167.0 1092.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# #### 2. Compact visualization

# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

text = 'The students exam scores were all fantastic'
doc = nlp(text)

for token in doc:
    print(f"{token.text.ljust(10)} {token.lemma_.ljust(10)} {token.pos_.ljust(6)}")

options = {"compact": True, "color": "#FFD700", "bg": "#8A2BE2", "font": "Source Sans Pro", "add_lemma": True}
html_output = displacy.render(doc, style='dep', options=options)
# Out:
# The        the        DET
# students   student    NOUN
# exam       exam       NOUN
# scores     score      NOUN
# were       be         AUX
# all        all        PRON
# fantastic  fantastic  ADJ
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3cf21837b041484da4279cb598a7234c-0" class="displacy" width="1100" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #FFD700; background: #8A2BE2; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">students</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="200">student</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">exam</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="350">exam</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">scores</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="500">score</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">were</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="650">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">all</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="800">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">fantastic</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="950">fantastic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3cf21837b041484da4279cb598a7234c-0-0" stroke-width="2px" d="M62,152.0 62,127.0 197.0,127.0 197.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3cf21837b041484da4279cb598a7234c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,154.0 L58,146.0 66,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3cf21837b041484da4279cb598a7234c-0-1" stroke-width="2px" d="M212,152.0 212,102.0 500.0,102.0 500.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3cf21837b041484da4279cb598a7234c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,154.0 L208,146.0 216,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3cf21837b041484da4279cb598a7234c-0-2" stroke-width="2px" d="M362,152.0 362,127.0 497.0,127.0 497.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3cf21837b041484da4279cb598a7234c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,154.0 L358,146.0 366,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3cf21837b041484da4279cb598a7234c-0-3" stroke-width="2px" d="M512,152.0 512,127.0 647.0,127.0 647.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3cf21837b041484da4279cb598a7234c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,154.0 L508,146.0 516,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3cf21837b041484da4279cb598a7234c-0-4" stroke-width="2px" d="M662,152.0 662,127.0 797.0,127.0 797.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3cf21837b041484da4279cb598a7234c-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M797.0,154.0 L801.0,146.0 793.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3cf21837b041484da4279cb598a7234c-0-5" stroke-width="2px" d="M662,152.0 662,102.0 950.0,102.0 950.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3cf21837b041484da4279cb598a7234c-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M950.0,154.0 L954.0,146.0 946.0,146.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# #### 3. Dependency parsing for a given sentence, changing background color and printing lemmas separately

# %%
import spacy
from spacy import displacy

nlp = spacy.load("lt_core_news_sm")

text = "žmogus be mokslo kaip namai be langų"
doc = nlp(text)

options = {"compact": False, "color": "#FFD700", "bg": "#8A2BE2", "font": "Source Sans Pro", "add_lemma": True}

html_output = displacy.render(doc, style='dep', options=options, page=True)

for token in doc:
    print(f"{token.text.ljust(10)} {token.lemma_.ljust(10)} {token.pos_.ljust(6)} {(token.head.text.ljust(10))} {(token.dep_.ljust(8))} ")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="lt">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="lt" id="d6eb1a21f5d7452ba2f58c3f10cbdeac-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #FFD700; background: #8A2BE2; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">žmogus</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="50">žmogus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">be</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="225">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">mokslo</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="400">mokslas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">kaip</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="575">kaip</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">namai</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="750">namas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">be</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="925">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">langų</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="1100">langas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d6eb1a21f5d7452ba2f58c3f10cbdeac-0-0" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d6eb1a21f5d7452ba2f58c3f10cbdeac-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d6eb1a21f5d7452ba2f58c3f10cbdeac-0-1" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d6eb1a21f5d7452ba2f58c3f10cbdeac-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl:arg</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,266.5 L403.0,254.5 387.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d6eb1a21f5d7452ba2f58c3f10cbdeac-0-2" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d6eb1a21f5d7452ba2f58c3f10cbdeac-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d6eb1a21f5d7452ba2f58c3f10cbdeac-0-3" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d6eb1a21f5d7452ba2f58c3f10cbdeac-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,266.5 L753.0,254.5 737.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d6eb1a21f5d7452ba2f58c3f10cbdeac-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d6eb1a21f5d7452ba2f58c3f10cbdeac-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d6eb1a21f5d7452ba2f58c3f10cbdeac-0-5" stroke-width="2px" d="M70,264.5 C70,2.0 1100.0,2.0 1100.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d6eb1a21f5d7452ba2f58c3f10cbdeac-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,266.5 L1108.0,254.5 1092.0,254.5" fill="currentColor"/>
# </g>
# </svg>
# </figure>
# </body>
# </html></span>
# žmogus     žmogus     NOUN   žmogus     ROOT
# be         be         ADP    mokslo     case
# mokslo     mokslas    NOUN   žmogus     obl:arg
# kaip       kaip       SCONJ  namai      mark
# namai      namas      NOUN   mokslo     nmod
# be         be         ADP    langų      case
# langų      langas     NOUN   žmogus     obl

# %% [markdown]
# #### 4. Generating context-free grammar (CFG)

# %%
import nltk

# Sentences with corresponding context-free grammar (CFG)
sentences = [
    {
        "text": "Mary saw Bob", 
        "grammar": """
            S -> NP VP
            NP -> 'Mary' | 'Bob'
            VP -> V NP
            V -> 'saw'         
        """
    },
    {
        "text": "The dog saw a man in the park", 
        "grammar": """
            S -> NP VP
            NP -> Det N | Det N PP
            Det -> 'The' | 'a' | 'the'
            N -> 'dog' | 'man' | 'park'
            VP -> V NP PP | V NP
            V -> 'saw'
            PP -> P NP
            P -> 'in'
        """
    },
    {
        "text": "A student wrote the equation", 
        "grammar": """
            S -> NP VP
            NP -> Det N
            VP -> V NP
            Det -> 'A' | 'the'
            N -> 'student' | 'equation'
            V -> 'wrote'
        """
    },
    {
        "text": "The angry bear chased the frightened little squirrel", 
        "grammar": """
            S -> NP VP
            NP -> Det Nom
            Det -> 'The' | 'the'
            Nom -> Adj Nom | Adj N
            Adj -> 'angry' | 'frightened' | 'little'
            N -> 'bear' | 'squirrel'
            VP -> V NP
            V -> 'chased'
        """
    }
]

for i, item in enumerate(sentences):
    # Converting grammar strings to NLTK CFG
    grammar = nltk.CFG.fromstring(item["grammar"])
    # Parsing using CFG
    parser = nltk.ChartParser(grammar)
    text = item["text"]
    print(f" {text}\n")
    for tree in parser.parse(text.split()):
        tree.pretty_print()
# Out:
#  Mary saw Bob
#
#       S
#   ____|___
#  |        VP
#  |     ___|___
#  NP   V       NP
#  |    |       |
# Mary saw     Bob
#
#  The dog saw a man in the park
#
#                  S
#       ___________|_______
#      |                   VP
#      |        ___________|_______
#      |       |       |           PP
#      |       |       |        ___|___
#      NP      |       NP      |       NP
#   ___|___    |    ___|___    |    ___|___
# Det      N   V  Det      N   P  Det      N
#  |       |   |   |       |   |   |       |
# The     dog saw  a      man  in the     park
#
#                  S
#       ___________|___
#      |               VP
#      |        _______|___
#      |       |           NP
#      |       |    _______|___
#      |       |   |   |       PP
#      |       |   |   |    ___|___
#      NP      |   |   |   |       NP
#   ___|___    |   |   |   |    ___|___
# Det      N   V  Det  N   P  Det      N
#  |       |   |   |   |   |   |       |
# The     dog saw  a  man  in the     park
#
#  A student wrote the equation
#
#                   S
#       ____________|____
#      |                 VP
#      |             ____|___
#      NP           |        NP
#   ___|_____       |     ___|_____
# Det        N      V   Det        N
#  |         |      |    |         |
#  A      student wrote the     equation
#
#  The angry bear chased the frightened little squirrel
#
#                      S
#        ______________|____________
#       |                           VP
#       |               ____________|_______
#       |              |                    NP
#       |              |      ______________|____
#       NP             |     |                  Nom
#   ____|____          |     |       ____________|_____
#  |        Nom        |     |      |                 Nom
#  |     ____|___      |     |      |             _____|_____
# Det  Adj       N     V    Det    Adj          Adj          N
#  |    |        |     |     |      |            |           |
# The angry     bear chased the frightened     little     squirrel
